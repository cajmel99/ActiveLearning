# %%
import os
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
import category_encoders as ce
from sklearn.metrics import precision_recall_fscore_support, confusion_matrix, accuracy_score
import keel_ds
from collections import Counter

# %% [markdown]
# # Load Data

# %%
k = keel_ds.list_data()
imbalanced_datasets_names = k[-1] # Imbalanced datasets

# %%
# Take a look for each dataset
imbalanced_datasets_proper = []
dataset_details = []

for dataset in imbalanced_datasets_names:
    print(dataset)
    missing_datasets = ['vowel.npz', 'breast.npz', 'housevotes.npz', 'bupa.npz', 'zoo-3.npz', 'abalone9-18.npz', 'ecoli-0-3-4_vs_5.npz', 'glass4', 'lymphography-normal-fibrosis.npz', 'ecoli-0-1-3-7_vs_2-6.npz', 'shuttle-c2-vs-c4.npz', 'winequality-white-9_vs_4.npz'] # Wrong dataset name in imbalance set (error in library)
    
    if dataset in missing_datasets:
      continue

    dataset = dataset.replace('.npz', '')
    imbalanced_datasets_proper.append(dataset)
    df = keel_ds.load_data(dataset, imbalanced=True, raw=True)

    # Get the number of samples and features
    n_samples = df.shape[0]
    n_features = df.shape[1] - 1 
    
    # imbalance ratio
    class_counts = Counter(df.iloc[:, -1])
    print(class_counts)
    majority_class = max(class_counts.values())
    minority_class = min(class_counts.values())
    imbalance_ratio =  minority_class/majority_class
    
    print(f"Class counts: {class_counts}")
    print(f"Imbalance ratio: {imbalance_ratio}")
    
    dataset_details.append({
       'Dataset': dataset,
       'Samples': n_samples,
       'Features': n_features,
       'Imbalance Ratio': imbalance_ratio
       })

details_df = pd.DataFrame(dataset_details)
# Out:
# yeast3.npz
# Counter({' negative': 1321, ' positive': 163})
# Class counts: Counter({' negative': 1321, ' positive': 163})
# Imbalance ratio: 0.12339137017411052
# yeast-0-2-5-6_vs_3-7-8-9.npz
# Counter({'negative': 905, 'positive': 99})
# Class counts: Counter({'negative': 905, 'positive': 99})
# Imbalance ratio: 0.10939226519337017
# kr-vs-k-one_vs_fifteen.npz
# Counter({'negative': 2166, 'positive': 78})
# Class counts: Counter({'negative': 2166, 'positive': 78})
# Imbalance ratio: 0.036011080332409975
# page-blocks0.npz
# Counter({' negative': 4913, ' positive': 559})
# Class counts: Counter({' negative': 4913, ' positive': 559})
# Imbalance ratio: 0.11377976796254834
# glass-0-1-5_vs_2.npz
# Counter({'negative': 155, 'positive': 17})
# Class counts: Counter({'negative': 155, 'positive': 17})
# Imbalance ratio: 0.10967741935483871
# kr-vs-k-zero-one_vs_draw.npz
# Counter({'negative': 2796, 'positive': 105})
# Class counts: Counter({'negative': 2796, 'positive': 105})
# Imbalance ratio: 0.03755364806866953
# led7digit-0-2-4-5-6-7-8-9_vs_1.npz
# Counter({'negative': 406, 'positive': 37})
# Class counts: Counter({'negative': 406, 'positive': 37})
# Imbalance ratio: 0.09113300492610837
# dermatology-6.npz
# Counter({'negative': 338, 'positive': 20})
# Class counts: Counter({'negative': 338, 'positive': 20})
# Imbalance ratio: 0.05917159763313609
# zoo-3.npz
# yeast1.npz
# Counter({' negative': 1055, ' positive': 429})
# Class counts: Counter({' negative': 1055, ' positive': 429})
# Imbalance ratio: 0.4066350710900474
# yeast-0-2-5-7-9_vs_3-6-8.npz
# Counter({'negative': 905, 'positive': 99})
# Class counts: Counter({'negative': 905, 'positive': 99})
# Imbalance ratio: 0.10939226519337017
# vowel0.npz
# Counter({' negative': 898, ' positive': 90})
# Class counts: Counter({' negative': 898, ' positive': 90})
# Imbalance ratio: 0.10022271714922049
# yeast5.npz
# Counter({' negative': 1440, ' positive': 44})
# Class counts: Counter({' negative': 1440, ' positive': 44})
# Imbalance ratio: 0.030555555555555555
# vehicle0.npz
# Counter({' negative': 647, ' positive': 199})
# Class counts: Counter({' negative': 647, ' positive': 199})
# Imbalance ratio: 0.3075734157650695
# vowel.npz
# winequality-white-3-9_vs_5.npz
# Counter({'negative': 1457, 'positive': 25})
# Class counts: Counter({'negative': 1457, 'positive': 25})
# Imbalance ratio: 0.017158544955387784
# winequality-red-4.npz
# Counter({'negative': 1546, 'positive': 53})
# Class counts: Counter({'negative': 1546, 'positive': 53})
# Imbalance ratio: 0.03428201811125485
# vehicle1.npz
# Counter({' negative': 629, ' positive': 217})
# Class counts: Counter({' negative': 629, ' positive': 217})
# Imbalance ratio: 0.3449920508744038
# yeast4.npz
# Counter({' negative': 1433, ' positive': 51})
# Class counts: Counter({' negative': 1433, ' positive': 51})
# Imbalance ratio: 0.03558967201674808
# shuttle-c0-vs-c4.npz
# Counter({'negative': 1706, 'positive': 123})
# Class counts: Counter({'negative': 1706, 'positive': 123})
# Imbalance ratio: 0.07209847596717468
# yeast6.npz
# Counter({' negative': 1449, ' positive': 35})
# Class counts: Counter({' negative': 1449, ' positive': 35})
# Imbalance ratio: 0.024154589371980676
# vehicle3.npz
# Counter({' negative': 634, ' positive': 212})
# Class counts: Counter({' negative': 634, ' positive': 212})
# Imbalance ratio: 0.334384858044164
# ecoli-0-1_vs_5.npz
# Counter({'negative': 220, 'positive': 20})
# Class counts: Counter({'negative': 220, 'positive': 20})
# Imbalance ratio: 0.09090909090909091
# breast.npz
# vehicle2.npz
# Counter({' negative': 628, ' positive ': 218})
# Class counts: Counter({' negative': 628, ' positive ': 218})
# Imbalance ratio: 0.3471337579617834
# ecoli-0-6-7_vs_3-5.npz
# Counter({'negative': 200, 'positive': 22})
# Class counts: Counter({'negative': 200, 'positive': 22})
# Imbalance ratio: 0.11
# glass2.npz
# Counter({' negative': 197, ' positive': 17})
# Class counts: Counter({' negative': 197, ' positive': 17})
# Imbalance ratio: 0.08629441624365482
# page-blocks-1-3_vs_4.npz
# Counter({'negative': 444, 'positive': 28})
# Class counts: Counter({'negative': 444, 'positive': 28})
# Imbalance ratio: 0.06306306306306306
# kddcup-buffer_overflow_vs_back.npz
# Counter({'negative': 2203, 'positive': 30})
# Class counts: Counter({'negative': 2203, 'positive': 30})
# Imbalance ratio: 0.013617793917385384
# glass0.npz
# Counter({' negative': 144, ' positive': 70})
# Class counts: Counter({' negative': 144, ' positive': 70})
# Imbalance ratio: 0.4861111111111111
# yeast-0-5-6-7-9_vs_4.npz
# Counter({'negative': 477, 'positive': 51})
# Class counts: Counter({'negative': 477, 'positive': 51})
# Imbalance ratio: 0.1069182389937107
# yeast-2_vs_4.npz
# Counter({'negative': 463, 'positive': 51})
# Class counts: Counter({'negative': 463, 'positive': 51})
# Imbalance ratio: 0.1101511879049676
# shuttle-6_vs_2-3.npz
# Counter({'negative': 220, 'positive': 10})
# Class counts: Counter({'negative': 220, 'positive': 10})
# Imbalance ratio: 0.045454545454545456
# glass1.npz
# Counter({' negative': 138, ' positive': 76})
# Class counts: Counter({' negative': 138, ' positive': 76})
# Imbalance ratio: 0.5507246376811594
# kddcup-rootkit-imap_vs_back.npz
# Counter({'negative': 2203, 'positive': 22})
# Class counts: Counter({'negative': 2203, 'positive': 22})
# Imbalance ratio: 0.009986382206082615
# kddcup-land_vs_portsweep.npz
# Counter({'negative': 1040, 'positive': 21})
# Class counts: Counter({'negative': 1040, 'positive': 21})
# Imbalance ratio: 0.020192307692307693
# kddcup-land_vs_satan.npz
# Counter({'negative': 1589, 'positive': 21})
# Class counts: Counter({'negative': 1589, 'positive': 21})
# Imbalance ratio: 0.013215859030837005
# glass5.npz
# Counter({' negative': 205, ' positive': 9})
# Class counts: Counter({' negative': 205, ' positive': 9})
# Imbalance ratio: 0.04390243902439024
# shuttle-2_vs_5.npz
# Counter({'negative': 3267, 'positive': 49})
# Class counts: Counter({'negative': 3267, 'positive': 49})
# Imbalance ratio: 0.01499846954392409
# car-vgood.npz
# Counter({'negative': 1663, 'positive': 65})
# Class counts: Counter({'negative': 1663, 'positive': 65})
# Imbalance ratio: 0.039085989176187615
# glass-0-6_vs_5.npz
# Counter({'negative': 99, 'positive': 9})
# Class counts: Counter({'negative': 99, 'positive': 9})
# Imbalance ratio: 0.09090909090909091
# ecoli-0-2-6-7_vs_3-5.npz
# Counter({'negative': 202, 'positive': 22})
# Class counts: Counter({'negative': 202, 'positive': 22})
# Imbalance ratio: 0.10891089108910891
# glass4.npz
# Counter({' negative': 201, ' positive': 13})
# Class counts: Counter({' negative': 201, ' positive': 13})
# Imbalance ratio: 0.06467661691542288
# abalone9-18.npz
# ecoli-0-3-4_vs_5.npz
# glass6.npz
# Counter({' negative': 185, ' positive': 29})
# Class counts: Counter({' negative': 185, ' positive': 29})
# Imbalance ratio: 0.15675675675675677
# lymphography-normal-fibrosis.npz
# pima.npz
# Counter({'negative': 500, 'positive': 268})
# Class counts: Counter({'negative': 500, 'positive': 268})
# Imbalance ratio: 0.536
# abalone-20_vs_8-9-10.npz
# Counter({' negative': 1890, ' positive': 26})
# Class counts: Counter({' negative': 1890, ' positive': 26})
# Imbalance ratio: 0.013756613756613757
# ecoli-0-1-4-6_vs_5.npz
# Counter({'negative': 260, 'positive': 20})
# Class counts: Counter({'negative': 260, 'positive': 20})
# Imbalance ratio: 0.07692307692307693
# ecoli-0-2-3-4_vs_5.npz
# Counter({'negative': 182, 'positive': 20})
# Class counts: Counter({'negative': 182, 'positive': 20})
# Imbalance ratio: 0.10989010989010989
# ecoli-0-3-4-7_vs_5-6.npz
# Counter({'negative': 232, 'positive': 25})
# Class counts: Counter({'negative': 232, 'positive': 25})
# Imbalance ratio: 0.10775862068965517
# ecoli-0-1-4-7_vs_2-3-5-6.npz
# Counter({'negative': 307, 'positive': 29})
# Class counts: Counter({'negative': 307, 'positive': 29})
# Imbalance ratio: 0.09446254071661238
# ecoli4.npz
# Counter({' negative': 316, ' positive': 20})
# Class counts: Counter({' negative': 316, ' positive': 20})
# Imbalance ratio: 0.06329113924050633
# housevotes.npz
# kr-vs-k-zero_vs_fifteen.npz
# Counter({'negative': 2166, 'positive': 27})
# Class counts: Counter({'negative': 2166, 'positive': 27})
# Imbalance ratio: 0.012465373961218837
# ecoli-0-1-3-7_vs_2-6.npz
# abalone-19_vs_10-11-12-13.npz
# Counter({' negative': 1590, ' positive': 32})
# Class counts: Counter({' negative': 1590, ' positive': 32})
# Imbalance ratio: 0.02012578616352201
# new-thyroid1.npz
# Counter({' negative': 180, ' positive': 35})
# Class counts: Counter({' negative': 180, ' positive': 35})
# Imbalance ratio: 0.19444444444444445
# haberman.npz
# Counter({' negative': 225, ' positive': 81})
# Class counts: Counter({' negative': 225, ' positive': 81})
# Imbalance ratio: 0.36
# abalone-3_vs_11.npz
# Counter({' negative': 487, ' positive': 15})
# Class counts: Counter({' negative': 487, ' positive': 15})
# Imbalance ratio: 0.030800821355236138
# poker-8-9_vs_5.npz
# Counter({'negative': 2050, 'positive': 25})
# Class counts: Counter({'negative': 2050, 'positive': 25})
# Imbalance ratio: 0.012195121951219513
# yeast-0-3-5-9_vs_7-8.npz
# Counter({'negative': 456, 'positive': 50})
# Class counts: Counter({'negative': 456, 'positive': 50})
# Imbalance ratio: 0.10964912280701754
# glass-0-1-6_vs_5.npz
# Counter({'negative': 175, 'positive': 9})
# Class counts: Counter({'negative': 175, 'positive': 9})
# Imbalance ratio: 0.05142857142857143
# kr-vs-k-zero_vs_eight.npz
# Counter({'negative': 1433, 'positive': 27})
# Class counts: Counter({'negative': 1433, 'positive': 27})
# Imbalance ratio: 0.01884159106769016
# new-thyroid2.npz
# Counter({' negative': 180, ' positive': 35})
# Class counts: Counter({' negative': 180, ' positive': 35})
# Imbalance ratio: 0.19444444444444445
# ecoli-0-3-4-6_vs_5.npz
# Counter({'negative': 185, 'positive': 20})
# Class counts: Counter({'negative': 185, 'positive': 20})
# Imbalance ratio: 0.10810810810810811
# poker-8-9_vs_6.npz
# Counter({'negative': 1460, 'positive': 25})
# Class counts: Counter({'negative': 1460, 'positive': 25})
# Imbalance ratio: 0.017123287671232876
# ecoli2.npz
# Counter({' negative': 284, ' positive': 52})
# Class counts: Counter({' negative': 284, ' positive': 52})
# Imbalance ratio: 0.18309859154929578
# ecoli-0-4-6_vs_5.npz
# Counter({'negative': 183, 'positive': 20})
# Class counts: Counter({'negative': 183, 'positive': 20})
# Imbalance ratio: 0.1092896174863388
# poker-8_vs_6.npz
# Counter({'negative': 1460, 'positive': 17})
# Class counts: Counter({'negative': 1460, 'positive': 17})
# Imbalance ratio: 0.011643835616438357
# yeast-2_vs_8.npz
# Counter({' negative': 462, ' positive': 20})
# Class counts: Counter({' negative': 462, ' positive': 20})
# Imbalance ratio: 0.04329004329004329
# poker-9_vs_7.npz
# Counter({'negative': 236, 'positive': 8})
# Class counts: Counter({'negative': 236, 'positive': 8})
# Imbalance ratio: 0.03389830508474576
# ecoli-0_vs_1.npz
# Counter({' positive': 143, ' negative': 77})
# Class counts: Counter({' positive': 143, ' negative': 77})
# Imbalance ratio: 0.5384615384615384
# ecoli3.npz
# Counter({' negative': 301, ' positive': 35})
# Class counts: Counter({' negative': 301, ' positive': 35})
# Imbalance ratio: 0.11627906976744186
# cleveland-0_vs_4.npz
# Counter({'negative': 164, 'positive': 13})
# Class counts: Counter({'negative': 164, 'positive': 13})
# Imbalance ratio: 0.07926829268292683
# ecoli1.npz
# Counter({' negative': 259, ' positive': 77})
# Class counts: Counter({' negative': 259, ' positive': 77})
# Imbalance ratio: 0.2972972972972973
# glass-0-1-6_vs_2.npz
# Counter({'negative': 175, 'positive': 17})
# Class counts: Counter({'negative': 175, 'positive': 17})
# Imbalance ratio: 0.09714285714285714
# winequality-red-8_vs_6-7.npz
# Counter({'negative': 837, 'positive': 18})
# Class counts: Counter({'negative': 837, 'positive': 18})
# Imbalance ratio: 0.021505376344086023
# shuttle-c2-vs-c4.npz
# kddcup-guess_passwd_vs_satan.npz
# Counter({'negative': 1589, 'positive': 53})
# Class counts: Counter({'negative': 1589, 'positive': 53})
# Imbalance ratio: 0.03335431088735054
# abalone-21_vs_8.npz
# Counter({' negative': 567, ' positive': 14})
# Class counts: Counter({' negative': 567, ' positive': 14})
# Imbalance ratio: 0.024691358024691357
# abalone-17_vs_7-8-9-10.npz
# Counter({' negative': 2280, ' positive': 58})
# Class counts: Counter({' negative': 2280, ' positive': 58})
# Imbalance ratio: 0.02543859649122807
# glass-0-1-2-3_vs_4-5-6.npz
# Counter({' negative': 163, ' positive': 51})
# Class counts: Counter({' negative': 163, ' positive': 51})
# Imbalance ratio: 0.3128834355828221
# flare-F.npz
# Counter({' negative': 1023, ' positive': 43})
# Class counts: Counter({' negative': 1023, ' positive': 43})
# Imbalance ratio: 0.042033235581622676
# segment0.npz
# Counter({' negative': 1979, ' positive': 329})
# Class counts: Counter({' negative': 1979, ' positive': 329})
# Imbalance ratio: 0.1662455785750379
# winequality-white-3_vs_7.npz
# Counter({'negative': 880, 'positive': 20})
# Class counts: Counter({'negative': 880, 'positive': 20})
# Imbalance ratio: 0.022727272727272728
# winequality-red-3_vs_5.npz
# Counter({'negative': 681, 'positive': 10})
# Class counts: Counter({'negative': 681, 'positive': 10})
# Imbalance ratio: 0.014684287812041116
# wisconsin.npz
# Counter({' negative': 444, ' positive': 239})
# Class counts: Counter({' negative': 444, ' positive': 239})
# Imbalance ratio: 0.5382882882882883
# winequality-red-8_vs_6.npz
# Counter({'negative': 638, 'positive': 18})
# Class counts: Counter({'negative': 638, 'positive': 18})
# Imbalance ratio: 0.02821316614420063
# yeast-1-2-8-9_vs_7.npz
# Counter({'negative': 917, 'positive': 30})
# Class counts: Counter({'negative': 917, 'positive': 30})
# Imbalance ratio: 0.03271537622682661
# bupa.npz
# kr-vs-k-three_vs_eleven.npz
# Counter({'negative': 2854, 'positive': 81})
# Class counts: Counter({'negative': 2854, 'positive': 81})
# Imbalance ratio: 0.028381219341275403
# winequality-white-9_vs_4.npz
# glass-0-4_vs_5.npz
# Counter({'negative': 83, 'positive': 9})
# Class counts: Counter({'negative': 83, 'positive': 9})
# Imbalance ratio: 0.10843373493975904
# iris0.npz
# Counter({' negative': 100, ' positive': 50})
# Class counts: Counter({' negative': 100, ' positive': 50})
# Imbalance ratio: 0.5
# glass-0-1-4-6_vs_2.npz
# Counter({'negative': 188, 'positive': 17})
# Class counts: Counter({'negative': 188, 'positive': 17})
# Imbalance ratio: 0.09042553191489362
# car-good.npz
# Counter({'negative': 1659, 'positive': 69})
# Class counts: Counter({'negative': 1659, 'positive': 69})
# Imbalance ratio: 0.04159132007233273
# ecoli-0-6-7_vs_5.npz
# Counter({'negative': 200, 'positive': 20})
# Class counts: Counter({'negative': 200, 'positive': 20})
# Imbalance ratio: 0.1
# yeast-1-4-5-8_vs_7.npz
# Counter({'negative': 663, 'positive': 30})
# Class counts: Counter({'negative': 663, 'positive': 30})
# Imbalance ratio: 0.04524886877828054
# ecoli-0-1_vs_2-3-5.npz
# Counter({'negative': 220, 'positive': 24})
# Class counts: Counter({'negative': 220, 'positive': 24})
# Imbalance ratio: 0.10909090909090909
# abalone19.npz
# Counter({'negative': 4142, ' positive': 32})
# Class counts: Counter({'negative': 4142, ' positive': 32})
# Imbalance ratio: 0.00772573635924674
# ecoli-0-1-4-7_vs_5-6.npz
# Counter({'negative': 307, 'positive': 25})
# Class counts: Counter({'negative': 307, 'positive': 25})
# Imbalance ratio: 0.08143322475570032
# yeast-1_vs_7.npz
# Counter({'negative': 429, 'positive': 30})
# Class counts: Counter({'negative': 429, 'positive': 30})
# Imbalance ratio: 0.06993006993006994

# %%
details_df
# Out:
#                      Dataset  Samples  Features  Imbalance Ratio
# 0                     yeast3     1484         8         0.123391
# 1   yeast-0-2-5-6_vs_3-7-8-9     1004         8         0.109392
# 2     kr-vs-k-one_vs_fifteen     2244         6         0.036011
# 3               page-blocks0     5472        10         0.113780
# 4           glass-0-1-5_vs_2      172         9         0.109677
# ..                       ...      ...       ...              ...
# 88        yeast-1-4-5-8_vs_7      693         8         0.045249
# 89        ecoli-0-1_vs_2-3-5      244         7         0.109091
# 90                 abalone19     4174         8         0.007726
# 91      ecoli-0-1-4-7_vs_5-6      332         6         0.081433
# 92              yeast-1_vs_7      459         7         0.069930
#
# [93 rows x 4 columns]

# %%
# Save data
file_name = "datasets_details.csv"
details_df.to_csv(file_name, index=False)
